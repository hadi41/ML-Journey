# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import models, layers, optimizers, regularizers
from tensorflow.keras.datasets import imdb

# %%
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words = 10000)

X_train_full = np.zeros((25_000, 10_000))

for i in range(25_000):
    for j in train_data[i]:
        X_train_full[i][j] = 1
        
X_test = np.zeros((25_000, 10_000))

for i in range(25_000):
    for j in test_data[i]:
        X_test[i][j] = 1
        
y_train_full, y_test = train_labels, test_labels

X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full, 
                                                      test_size = 5_000, random_state = 0)

print('''
For detail on data preprocessing,
see Chapter 3 a
''')
# Out:
# For detail on data preprocessing,
# see Chapter 3 a

# %%
model_original = models.Sequential([
    layers.Dense(16, activation = 'relu', input_shape = (10_000,)),
    layers.Dense(16, activation = 'relu'),
    layers.Dense(1, activation = 'sigmoid')
])

model_original.compile(loss = 'binary_crossentropy',
                      optimizer = 'adam',
                      metrics = ['accuracy'])

# %%
model_underfit = models.Sequential([
    layers.Dense(4, activation = 'relu', input_shape = (10_000,)),
    layers.Dense(4, activation = 'relu'),
    layers.Dense(1, activation = 'sigmoid')
])

model_underfit.compile(loss = 'binary_crossentropy',
                      optimizer = 'adam',
                      metrics = ['accuracy'])

# %%
model_overfit = models.Sequential([
    layers.Dense(128, activation = 'relu', input_shape = (10_000,)),
    layers.Dense(128, activation = 'relu'),
    layers.Dense(1, activation = 'sigmoid')
])

model_overfit.compile(loss = 'binary_crossentropy',
                      optimizer = 'adam',
                      metrics = ['accuracy'])

# %%
history_underfit = model_underfit.fit(X_train, y_train, validation_data = (X_valid, y_valid), 
                   verbose = True, batch_size = 128, epochs = 20)
history_original = model_original.fit(X_train, y_train, validation_data = (X_valid, y_valid), 
                   verbose = True, batch_size = 128, epochs = 20)
history_overfit = model_overfit.fit(X_train, y_train, validation_data = (X_valid, y_valid), 
                   verbose = True, batch_size = 128, epochs = 20)
# Out:
# Epoch 1/20
# 157/157 [==============================] - 1s 3ms/step - loss: 0.5641 - accuracy: 0.7379 - val_loss: 0.4674 - val_accuracy: 0.8486
# Epoch 2/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.3926 - accuracy: 0.9013 - val_loss: 0.3546 - val_accuracy: 0.8948
# Epoch 3/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.2196 - accuracy: 0.9356 - val_loss: 0.2827 - val_accuracy: 0.8924
# Epoch 4/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1453 - accuracy: 0.9538 - val_loss: 0.2858 - val_accuracy: 0.8894
# Epoch 5/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1063 - accuracy: 0.9675 - val_loss: 0.3219 - val_accuracy: 0.8878
# Epoch 6/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0790 - accuracy: 0.9776 - val_loss: 0.3662 - val_accuracy: 0.8878
# Epoch 7/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0577 - accuracy: 0.9855 - val_loss: 0.4288 - val_accuracy: 0.8816
# Epoch 8/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0419 - accuracy: 0.9912 - val_loss: 0.4597 - val_accuracy: 0.8810
# Epoch 9/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0303 - accuracy: 0.9949 - val_loss: 0.5043 - val_accuracy: 0.8770
# Epoch 10/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0223 - accuracy: 0.9967 - val_loss: 0.5456 - val_accuracy: 0.8790
# Epoch 11/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0162 - accuracy: 0.9980 - val_loss: 0.5888 - val_accuracy: 0.8786
# Epoch 12/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0119 - accuracy: 0.9983 - val_loss: 0.6443 - val_accuracy: 0.8762
# Epoch 13/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0093 - accuracy: 0.9984 - val_loss: 0.6631 - val_accuracy: 0.8782
# Epoch 14/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0074 - accuracy: 0.9984 - val_loss: 0.7060 - val_accuracy: 0.8774
# Epoch 15/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0060 - accuracy: 0.9985 - val_loss: 0.7234 - val_accuracy: 0.8778
# Epoch 16/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0050 - accuracy: 0.9985 - val_loss: 0.7592 - val_accuracy: 0.8768
# Epoch 17/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0042 - accuracy: 0.9985 - val_loss: 0.7873 - val_accuracy: 0.8764
# Epoch 18/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0036 - accuracy: 0.9985 - val_loss: 0.8112 - val_accuracy: 0.8772
# Epoch 19/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0031 - accuracy: 0.9985 - val_loss: 0.8351 - val_accuracy: 0.8764
# Epoch 20/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0028 - accuracy: 0.9985 - val_loss: 0.8614 - val_accuracy: 0.8762
# Epoch 1/20
# 157/157 [==============================] - 1s 4ms/step - loss: 0.3959 - accuracy: 0.8410 - val_loss: 0.2797 - val_accuracy: 0.8862
# Epoch 2/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1971 - accuracy: 0.9286 - val_loss: 0.2700 - val_accuracy: 0.8934
# Epoch 3/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1380 - accuracy: 0.9516 - val_loss: 0.3223 - val_accuracy: 0.8828
# Epoch 4/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0967 - accuracy: 0.9682 - val_loss: 0.3552 - val_accuracy: 0.8832
# Epoch 5/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0666 - accuracy: 0.9799 - val_loss: 0.4111 - val_accuracy: 0.8784
# Epoch 6/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0417 - accuracy: 0.9898 - val_loss: 0.4758 - val_accuracy: 0.8780
# Epoch 7/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0231 - accuracy: 0.9959 - val_loss: 0.5540 - val_accuracy: 0.8758
# Epoch 8/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0116 - accuracy: 0.9987 - val_loss: 0.6189 - val_accuracy: 0.8750
# Epoch 9/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0058 - accuracy: 0.9994 - val_loss: 0.6878 - val_accuracy: 0.8754
# Epoch 10/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0034 - accuracy: 0.9996 - val_loss: 0.7386 - val_accuracy: 0.8746
# Epoch 11/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 0.7873 - val_accuracy: 0.8738
# Epoch 12/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 0.9999 - val_loss: 0.8132 - val_accuracy: 0.8758
# Epoch 13/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 0.9999 - val_loss: 0.8489 - val_accuracy: 0.8756
# Epoch 14/20
# 157/157 [==============================] - 0s 2ms/step - loss: 8.0675e-04 - accuracy: 0.9999 - val_loss: 0.8816 - val_accuracy: 0.8748
# Epoch 15/20
# 157/157 [==============================] - 0s 2ms/step - loss: 6.2393e-04 - accuracy: 1.0000 - val_loss: 0.9103 - val_accuracy: 0.8742
# Epoch 16/20
# 157/157 [==============================] - 0s 2ms/step - loss: 5.0237e-04 - accuracy: 1.0000 - val_loss: 0.9303 - val_accuracy: 0.8746
# Epoch 17/20
# 157/157 [==============================] - 0s 2ms/step - loss: 4.0605e-04 - accuracy: 1.0000 - val_loss: 0.9606 - val_accuracy: 0.8746
# Epoch 18/20
# 157/157 [==============================] - 0s 2ms/step - loss: 3.3406e-04 - accuracy: 1.0000 - val_loss: 0.9815 - val_accuracy: 0.8742
# Epoch 19/20
# 157/157 [==============================] - 0s 2ms/step - loss: 2.7885e-04 - accuracy: 1.0000 - val_loss: 1.0058 - val_accuracy: 0.8736
# Epoch 20/20
# 157/157 [==============================] - 0s 2ms/step - loss: 2.3625e-04 - accuracy: 1.0000 - val_loss: 1.0298 - val_accuracy: 0.8732
# Epoch 1/20
# 157/157 [==============================] - 1s 8ms/step - loss: 0.3368 - accuracy: 0.8612 - val_loss: 0.2730 - val_accuracy: 0.8868
# Epoch 2/20
# 157/157 [==============================] - 1s 6ms/step - loss: 0.1617 - accuracy: 0.9395 - val_loss: 0.3099 - val_accuracy: 0.8848
# Epoch 3/20
# 157/157 [==============================] - 1s 6ms/step - loss: 0.0770 - accuracy: 0.9729 - val_loss: 0.3812 - val_accuracy: 0.8818
# Epoch 4/20
# 157/157 [==============================] - 1s 7ms/step - loss: 0.0218 - accuracy: 0.9935 - val_loss: 0.4997 - val_accuracy: 0.8814
# Epoch 5/20
# 157/157 [==============================] - 1s 7ms/step - loss: 0.0048 - accuracy: 0.9992 - val_loss: 0.6634 - val_accuracy: 0.8810
# Epoch 6/20
# 157/157 [==============================] - 1s 7ms/step - loss: 8.7010e-04 - accuracy: 1.0000 - val_loss: 0.7360 - val_accuracy: 0.8832
# Epoch 7/20
# 157/157 [==============================] - 1s 7ms/step - loss: 2.4572e-04 - accuracy: 1.0000 - val_loss: 0.7901 - val_accuracy: 0.8838
# Epoch 8/20
# 157/157 [==============================] - 1s 6ms/step - loss: 1.3083e-04 - accuracy: 1.0000 - val_loss: 0.8248 - val_accuracy: 0.8838
# Epoch 9/20
# 157/157 [==============================] - 1s 7ms/step - loss: 9.0105e-05 - accuracy: 1.0000 - val_loss: 0.8530 - val_accuracy: 0.8840
# Epoch 10/20
# 157/157 [==============================] - 1s 7ms/step - loss: 6.7103e-05 - accuracy: 1.0000 - val_loss: 0.8760 - val_accuracy: 0.8840
# Epoch 11/20
# 157/157 [==============================] - 1s 6ms/step - loss: 5.0846e-05 - accuracy: 1.0000 - val_loss: 0.8972 - val_accuracy: 0.8838
# Epoch 12/20
# 157/157 [==============================] - 1s 6ms/step - loss: 4.0485e-05 - accuracy: 1.0000 - val_loss: 0.9151 - val_accuracy: 0.8836
# Epoch 13/20
# 157/157 [==============================] - 1s 6ms/step - loss: 3.2994e-05 - accuracy: 1.0000 - val_loss: 0.9313 - val_accuracy: 0.8834
# Epoch 14/20
# 157/157 [==============================] - 1s 7ms/step - loss: 2.7218e-05 - accuracy: 1.0000 - val_loss: 0.9466 - val_accuracy: 0.8832
# Epoch 15/20
# 157/157 [==============================] - 1s 7ms/step - loss: 2.2703e-05 - accuracy: 1.0000 - val_loss: 0.9610 - val_accuracy: 0.8836
# Epoch 16/20
# 157/157 [==============================] - 1s 7ms/step - loss: 1.9139e-05 - accuracy: 1.0000 - val_loss: 0.9742 - val_accuracy: 0.8838
# Epoch 17/20
# 157/157 [==============================] - 1s 7ms/step - loss: 1.6269e-05 - accuracy: 1.0000 - val_loss: 0.9874 - val_accuracy: 0.8834
# Epoch 18/20
# 157/157 [==============================] - 1s 7ms/step - loss: 1.3944e-05 - accuracy: 1.0000 - val_loss: 0.9995 - val_accuracy: 0.8832
# Epoch 19/20
# 157/157 [==============================] - 1s 7ms/step - loss: 1.2013e-05 - accuracy: 1.0000 - val_loss: 1.0114 - val_accuracy: 0.8832
# Epoch 20/20
# 157/157 [==============================] - 1s 7ms/step - loss: 1.0393e-05 - accuracy: 1.0000 - val_loss: 1.0230 - val_accuracy: 0.8836

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 5))

ax[0].plot(np.arange(1, 11), history_underfit.history['val_loss'][:10], label = 'underfit')
ax[0].plot(np.arange(1, 11), history_original.history['val_loss'][:10], label = 'original')
ax[0].plot(np.arange(1, 11), history_overfit.history['val_loss'][:10], label = 'overfit')
ax[0].set_xlabel('Epoch'); ax[0].set_ylabel('Loss'); ax[0].set_title('Validation')
ax[0].legend(); ax[0].grid()

ax[1].plot(np.arange(1, 11), history_underfit.history['loss'][:10], label = 'underfit')
ax[1].plot(np.arange(1, 11), history_original.history['loss'][:10], label = 'original')
ax[1].plot(np.arange(1, 11), history_overfit.history['loss'][:10], label = 'overfit')
ax[1].set_xlabel('Epoch'); ax[1].set_ylabel('Loss'); ax[1].set_title('Training')
ax[1].legend(); ax[1].grid()

plt.show()

# %%
print('''
Let's add some regularizers
''')
# Out:
# Let's add some regularizers

# %%
model_l2_01 = models.Sequential([
    layers.Dense(16, activation = 'relu', input_shape = (10_000,), 
                 kernel_regularizer = regularizers.l2(0.01)),
    layers.Dense(16, activation = 'relu', 
                 kernel_regularizer = regularizers.l2(0.01)),
    layers.Dense(1, activation = 'sigmoid')
])

model_l2_01.compile(loss = 'binary_crossentropy',
                      optimizer = 'adam',
                      metrics = ['accuracy'])

model_l2_001 = models.Sequential([
    layers.Dense(16, activation = 'relu', input_shape = (10_000,), 
                 kernel_regularizer = regularizers.l2(0.001)),
    layers.Dense(16, activation = 'relu', 
                 kernel_regularizer = regularizers.l2(0.001)),
    layers.Dense(1, activation = 'sigmoid')
])

model_l2_001.compile(loss = 'binary_crossentropy',
                      optimizer = 'adam',
                      metrics = ['accuracy'])

model_l1_001 = models.Sequential([
    layers.Dense(16, activation = 'relu', input_shape = (10_000,), 
                 kernel_regularizer = regularizers.l1(0.001)),
    layers.Dense(16, activation = 'relu', 
                 kernel_regularizer = regularizers.l1(0.001)),
    layers.Dense(1, activation = 'sigmoid')
])

model_l1_001.compile(loss = 'binary_crossentropy',
                      optimizer = 'adam',
                      metrics = ['accuracy'])

history_l2_01 = model_l2_01.fit(X_train, y_train, validation_data = (X_valid, y_valid), 
                   verbose = True, batch_size = 128, epochs = 20)
history_l2_001 = model_l2_001.fit(X_train, y_train, validation_data = (X_valid, y_valid), 
                   verbose = True, batch_size = 128, epochs = 20)
history_l1_001 = model_l1_001.fit(X_train, y_train, validation_data = (X_valid, y_valid), 
                   verbose = True, batch_size = 128, epochs = 20)
# Out:
# Epoch 1/20
# 157/157 [==============================] - 1s 4ms/step - loss: 0.6170 - accuracy: 0.8382 - val_loss: 0.4867 - val_accuracy: 0.8750
# Epoch 2/20
# 157/157 [==============================] - 0s 3ms/step - loss: 0.4575 - accuracy: 0.8881 - val_loss: 0.4491 - val_accuracy: 0.8802
# Epoch 3/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.4202 - accuracy: 0.8954 - val_loss: 0.4323 - val_accuracy: 0.8808
# Epoch 4/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.4043 - accuracy: 0.8970 - val_loss: 0.4165 - val_accuracy: 0.8820
# Epoch 5/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.3925 - accuracy: 0.8992 - val_loss: 0.4146 - val_accuracy: 0.8880
# Epoch 6/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.3823 - accuracy: 0.8996 - val_loss: 0.4086 - val_accuracy: 0.8832
# Epoch 7/20
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3701 - accuracy: 0.9049 - val_loss: 0.4011 - val_accuracy: 0.8852
# Epoch 8/20
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3612 - accuracy: 0.9083 - val_loss: 0.3988 - val_accuracy: 0.8840
# Epoch 9/20
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3548 - accuracy: 0.9095 - val_loss: 0.4053 - val_accuracy: 0.8818
# Epoch 10/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.3475 - accuracy: 0.9111 - val_loss: 0.3955 - val_accuracy: 0.8864
# Epoch 11/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.3440 - accuracy: 0.9136 - val_loss: 0.3919 - val_accuracy: 0.8846
# Epoch 12/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.3355 - accuracy: 0.9142 - val_loss: 0.4001 - val_accuracy: 0.8796
# Epoch 13/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.3270 - accuracy: 0.9193 - val_loss: 0.3889 - val_accuracy: 0.8884
# Epoch 14/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.3265 - accuracy: 0.9183 - val_loss: 0.3870 - val_accuracy: 0.8866
# Epoch 15/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.3193 - accuracy: 0.9191 - val_loss: 0.3882 - val_accuracy: 0.8830
# Epoch 16/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.3085 - accuracy: 0.9240 - val_loss: 0.3810 - val_accuracy: 0.8884
# Epoch 17/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.3031 - accuracy: 0.9267 - val_loss: 0.3801 - val_accuracy: 0.8876
# Epoch 18/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.2979 - accuracy: 0.9293 - val_loss: 0.3810 - val_accuracy: 0.8864
# Epoch 19/20
# 157/157 [==============================] - 0s 3ms/step - loss: 0.2936 - accuracy: 0.9300 - val_loss: 0.3879 - val_accuracy: 0.8848
# Epoch 20/20
# 157/157 [==============================] - 0s 3ms/step - loss: 0.2846 - accuracy: 0.9337 - val_loss: 0.3847 - val_accuracy: 0.8818
# Epoch 1/20
# 157/157 [==============================] - 1s 4ms/step - loss: 0.4267 - accuracy: 0.8421 - val_loss: 0.3192 - val_accuracy: 0.8944
# Epoch 2/20
# 157/157 [==============================] - 0s 3ms/step - loss: 0.2631 - accuracy: 0.9232 - val_loss: 0.3258 - val_accuracy: 0.8924
# Epoch 3/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.2303 - accuracy: 0.9396 - val_loss: 0.3646 - val_accuracy: 0.8780
# Epoch 4/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.2145 - accuracy: 0.9450 - val_loss: 0.3898 - val_accuracy: 0.8770
# Epoch 5/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.2049 - accuracy: 0.9499 - val_loss: 0.4077 - val_accuracy: 0.8750
# Epoch 6/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.2002 - accuracy: 0.9520 - val_loss: 0.4334 - val_accuracy: 0.8816
# Epoch 7/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1899 - accuracy: 0.9574 - val_loss: 0.4605 - val_accuracy: 0.8730
# Epoch 8/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1886 - accuracy: 0.9597 - val_loss: 0.4912 - val_accuracy: 0.8702
# Epoch 9/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1804 - accuracy: 0.9623 - val_loss: 0.4960 - val_accuracy: 0.8716
# Epoch 10/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1709 - accuracy: 0.9674 - val_loss: 0.5187 - val_accuracy: 0.8694
# Epoch 11/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1672 - accuracy: 0.9688 - val_loss: 0.5155 - val_accuracy: 0.8734
# Epoch 12/20
# 157/157 [==============================] - 0s 3ms/step - loss: 0.1625 - accuracy: 0.9714 - val_loss: 0.5377 - val_accuracy: 0.8698
# Epoch 13/20
# 157/157 [==============================] - 0s 3ms/step - loss: 0.1555 - accuracy: 0.9743 - val_loss: 0.5511 - val_accuracy: 0.8674
# Epoch 14/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1606 - accuracy: 0.9715 - val_loss: 0.5635 - val_accuracy: 0.8690
# Epoch 15/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1511 - accuracy: 0.9778 - val_loss: 0.6295 - val_accuracy: 0.8528
# Epoch 16/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1465 - accuracy: 0.9789 - val_loss: 0.5848 - val_accuracy: 0.8652
# Epoch 17/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1405 - accuracy: 0.9799 - val_loss: 0.6155 - val_accuracy: 0.8606
# Epoch 18/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1337 - accuracy: 0.9831 - val_loss: 0.6333 - val_accuracy: 0.8626
# Epoch 19/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1316 - accuracy: 0.9836 - val_loss: 0.6469 - val_accuracy: 0.8590
# Epoch 20/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1237 - accuracy: 0.9869 - val_loss: 0.6525 - val_accuracy: 0.8562
# Epoch 1/20
# 157/157 [==============================] - 1s 4ms/step - loss: 0.7825 - accuracy: 0.8159 - val_loss: 0.5579 - val_accuracy: 0.8574
# Epoch 2/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.5451 - accuracy: 0.8638 - val_loss: 0.5392 - val_accuracy: 0.8636
# Epoch 3/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.5163 - accuracy: 0.8749 - val_loss: 0.5127 - val_accuracy: 0.8728
# Epoch 4/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.4963 - accuracy: 0.8812 - val_loss: 0.5053 - val_accuracy: 0.8732
# Epoch 5/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.4851 - accuracy: 0.8874 - val_loss: 0.4937 - val_accuracy: 0.8748
# Epoch 6/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.4660 - accuracy: 0.8942 - val_loss: 0.5024 - val_accuracy: 0.8748
# Epoch 7/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.4594 - accuracy: 0.8979 - val_loss: 0.4826 - val_accuracy: 0.8810
# Epoch 8/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.4467 - accuracy: 0.9002 - val_loss: 0.4740 - val_accuracy: 0.8796
# Epoch 9/20
# 157/157 [==============================] - 0s 3ms/step - loss: 0.4383 - accuracy: 0.9039 - val_loss: 0.4806 - val_accuracy: 0.8834
# Epoch 10/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.4333 - accuracy: 0.9044 - val_loss: 0.4747 - val_accuracy: 0.8864
# Epoch 11/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.4230 - accuracy: 0.9072 - val_loss: 0.4894 - val_accuracy: 0.8734
# Epoch 12/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.4171 - accuracy: 0.9093 - val_loss: 0.4937 - val_accuracy: 0.8692
# Epoch 13/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.4121 - accuracy: 0.9101 - val_loss: 0.4729 - val_accuracy: 0.8838
# Epoch 14/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.4029 - accuracy: 0.9150 - val_loss: 0.4732 - val_accuracy: 0.8820
# Epoch 15/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.3949 - accuracy: 0.9163 - val_loss: 0.4697 - val_accuracy: 0.8806
# Epoch 16/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.3858 - accuracy: 0.9205 - val_loss: 0.4746 - val_accuracy: 0.8836
# Epoch 17/20
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3841 - accuracy: 0.9218 - val_loss: 0.4707 - val_accuracy: 0.8844
# Epoch 18/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.3748 - accuracy: 0.9238 - val_loss: 0.4846 - val_accuracy: 0.8784
# Epoch 19/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.3677 - accuracy: 0.9271 - val_loss: 0.4891 - val_accuracy: 0.8754
# Epoch 20/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.3618 - accuracy: 0.9295 - val_loss: 0.4936 - val_accuracy: 0.8786

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 5))

ax[0].plot(np.arange(1, 11), history_original.history['val_loss'][:10], label = 'original')
ax[0].plot(np.arange(1, 11), history_l2_001.history['val_loss'][:10], label = 'l2 = 0.001')
ax[0].plot(np.arange(1, 11), history_l2_01.history['val_loss'][:10], label = 'l2 = 0.01')
ax[0].plot(np.arange(1, 11), history_l1_001.history['val_loss'][:10], label = 'l1 = 0.001')
ax[0].set_xlabel('Epoch'); ax[0].set_ylabel('Loss'); ax[0].set_title('Validation')
ax[0].legend(); ax[0].grid()

ax[1].plot(np.arange(1, 11), history_original.history['loss'][:10], label = 'original')
ax[1].plot(np.arange(1, 11), history_l2_001.history['loss'][:10], label = 'l2 = 0.001')
ax[1].plot(np.arange(1, 11), history_l2_01.history['loss'][:10], label = 'l2 = 0.01')
ax[1].plot(np.arange(1, 11), history_l1_001.history['loss'][:10], label = 'l1 = 0.001')
ax[1].set_xlabel('Epoch'); ax[1].set_ylabel('Loss'); ax[1].set_title('Training')
ax[1].legend(); ax[1].grid()

plt.show()

# %%
print('''
There's also the l1_l2(l1 = 0.001, l2 = 0.001) regularizer
''')
# Out:
# There's also the l1_l2(l1 = 0.001, l2 = 0.001) regularizer

# %%
layer = layers.Dense(4, input_shape = (4,))
layer((tf.zeros((1, 4))))
print(np.array(layer.weights[0]))
weights = np.array(layer.weights[0]) + 1

fig, ax = plt.subplots(1, 2, figsize = (15, 5))
ax[0].imshow(weights, cmap = 'gray_r')
ax[0].set_title('Normal')
ax[1].imshow(weights * np.random.randint(0, 2, size = (4, 4)) * 2, cmap = 'gray_r')
ax[1].set_title('Dropped')
plt.show()
# Out:
# <tf.Variable 'dense_95/kernel:0' shape=(4, 4) dtype=float32, numpy=
# array([[-0.7114269 ,  0.47522742, -0.654242  , -0.81872886],
#        [-0.26497793, -0.5150465 , -0.25381565,  0.37703055],
#        [-0.26327616,  0.51673216, -0.32950395,  0.43301862],
#        [ 0.7959588 , -0.86028785,  0.35241765,  0.05451   ]],
#       dtype=float32)>

# %%
model_dropout = models.Sequential([
    layers.Dense(16, activation = 'relu', input_shape = (10_000,)),
    layers.Dropout(0.5),
    layers.Dense(16, activation = 'relu'),
    layers.Dropout(0.5),
    layers.Dense(1, activation = 'sigmoid')
])

model_dropout.compile(loss = 'binary_crossentropy',
                      optimizer = 'adam',
                      metrics = ['accuracy'])

history_dropout = model_dropout.fit(X_train, y_train, validation_data = (X_valid, y_valid), 
                                   verbose = True, batch_size = 128, epochs = 20)
# Out:
# Epoch 1/20
# 157/157 [==============================] - 1s 3ms/step - loss: 0.6135 - accuracy: 0.6738 - val_loss: 0.4749 - val_accuracy: 0.8752
# Epoch 2/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.4444 - accuracy: 0.8392 - val_loss: 0.3333 - val_accuracy: 0.8884
# Epoch 3/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.3519 - accuracy: 0.8778 - val_loss: 0.2978 - val_accuracy: 0.8936
# Epoch 4/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.2931 - accuracy: 0.9000 - val_loss: 0.2853 - val_accuracy: 0.8980
# Epoch 5/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.2620 - accuracy: 0.9115 - val_loss: 0.2751 - val_accuracy: 0.8908
# Epoch 6/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.2297 - accuracy: 0.9212 - val_loss: 0.2897 - val_accuracy: 0.8926
# Epoch 7/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.2158 - accuracy: 0.9259 - val_loss: 0.3258 - val_accuracy: 0.8910
# Epoch 8/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1945 - accuracy: 0.9336 - val_loss: 0.3164 - val_accuracy: 0.8924
# Epoch 9/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1803 - accuracy: 0.9366 - val_loss: 0.3294 - val_accuracy: 0.8874
# Epoch 10/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1704 - accuracy: 0.9404 - val_loss: 0.3809 - val_accuracy: 0.8882
# Epoch 11/20
# 157/157 [==============================] - 0s 3ms/step - loss: 0.1617 - accuracy: 0.9444 - val_loss: 0.3742 - val_accuracy: 0.8888
# Epoch 12/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1495 - accuracy: 0.9463 - val_loss: 0.4237 - val_accuracy: 0.8892
# Epoch 13/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1452 - accuracy: 0.9468 - val_loss: 0.4258 - val_accuracy: 0.8888
# Epoch 14/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1419 - accuracy: 0.9493 - val_loss: 0.4460 - val_accuracy: 0.8900
# Epoch 15/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1298 - accuracy: 0.9505 - val_loss: 0.4935 - val_accuracy: 0.8906
# Epoch 16/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1302 - accuracy: 0.9505 - val_loss: 0.4862 - val_accuracy: 0.8888
# Epoch 17/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1228 - accuracy: 0.9515 - val_loss: 0.5473 - val_accuracy: 0.8882
# Epoch 18/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1200 - accuracy: 0.9527 - val_loss: 0.5679 - val_accuracy: 0.8884
# Epoch 19/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1174 - accuracy: 0.9542 - val_loss: 0.5606 - val_accuracy: 0.8836
# Epoch 20/20
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1144 - accuracy: 0.9533 - val_loss: 0.6140 - val_accuracy: 0.8892

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 5))

ax[0].plot(np.arange(1, 11), history_original.history['val_loss'][:10], label = 'original')
ax[0].plot(np.arange(1, 11), history_dropout.history['val_loss'][:10], label = 'dropout')
ax[0].set_xlabel('Epoch'); ax[0].set_ylabel('Loss'); ax[0].set_title('Validation')
ax[0].legend(); ax[0].grid()

ax[1].plot(np.arange(1, 11), history_original.history['loss'][:10], label = 'original')
ax[1].plot(np.arange(1, 11), history_dropout.history['loss'][:10], label = 'dropout')
ax[1].set_xlabel('Epoch'); ax[1].set_ylabel('Loss'); ax[1].set_title('Training')
ax[1].legend(); ax[1].grid()

plt.show()
